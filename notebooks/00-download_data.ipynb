# %%
# Importação de bibliotecas
import pandas as pd

# %%
df = pd.read_csv('../data/raw/data.csv')
df.head()
display(df)
# Out:
#       ID  Age  Gender              Bedtime          Wakeup time  \
# 0      1   65  Female  2021-03-06 01:00:00  2021-03-06 07:00:00
# 1      2   69    Male  2021-12-05 02:00:00  2021-12-05 09:00:00
# 2      3   40  Female  2021-05-25 21:30:00  2021-05-25 05:30:00
# 3      4   40  Female  2021-11-03 02:30:00  2021-11-03 08:30:00
# 4      5   57    Male  2021-03-13 01:00:00  2021-03-13 09:00:00
# ..   ...  ...     ...                  ...                  ...
# 447  448   27  Female  2021-11-13 22:00:00  2021-11-13 05:30:00
# 448  449   52    Male  2021-03-31 21:00:00  2021-03-31 03:00:00
# 449  450   40  Female  2021-09-07 23:00:00  2021-09-07 07:30:00
# 450  451   45    Male  2021-07-29 21:00:00  2021-07-29 04:00:00
# 451  452   18    Male  2021-03-17 02:30:00  2021-03-17 10:00:00
#
#      Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0               6.0              0.88                    18
# 1               7.0              0.66                    19
# ...

# %%
dictionary = pd.DataFrame([
    {
        "variavel": "ID",
        "descricao": "Identificador único do indivíduo testado",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },    
    {
        "variavel": "Age",
        "descricao": "Idade do indivíduo testado, em anos",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },    
    {
        "variavel": "Gender",
        "descricao": "Gênero do indivíduo testado",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },    
    {
        "variavel": "Bedtime",
        "descricao": "O horário em que o indivíduo testado vai para a cama todas as noites",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },    
    {
        "variavel": "Wakeup time",
        "descricao": "O horário em que o indivíduo testado acorda todas as manhãs",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },    
    {
        "variavel": "Sleep duration",
        "descricao": "Quantidade total de tempo em que o indivíduo testado dormiu (em horas)",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },    
    {
        "variavel": "Sleep efficiency",
        "descricao": "Medida da proporção de tempo na cama gasto dormindo",
        "tipo": "quantitativa",
        "subtipo": "contínua"
    },    
    {
        "variavel": "REM sleep percentage",
        "descricao": "Percentual do tempo total gasto em sono REM",
        "tipo": "quantitativa",
        "subtipo": "discreta"
         },    
    {
        "variavel": "Deep sleep percentage",
        "descricao": "Percentual do tempo total gasto em sono profundo",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },    
    {
        "variavel": "Light sleep percentage",
        "descricao": "Percentual do tempo total gasto em sono leve",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },    
    {
        "variavel": "Awakenings",
        "descricao": "O número de vezes em que o indivíduo testado acorda durante a noite",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },    
    {
        "variavel": "Caffeine consumption",
        "descricao": "A quantidade de cafeína consumida nas 24 horas anteriores a hora de dormir (em mg)",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    },    
    {
        "variavel": "Alcohol consumption",
        "descricao": "A quantidade de álcool consumido nas 24 horas anteriores a hora de dormir (em oz)",
        "tipo": "quantitativa",
        "subtipo": "discreta"
         },    
    {
        "variavel": "Smoking status",
        "descricao": "Se o indivíduo testado é fumante ou não fumante",
        "tipo": "qualitativa",
        "subtipo": "nominal"
    },    
    {
        "variavel": "Exercise frequency",
        "descricao": "O número de vezes por semana que o indivíduo testado fez exercícios",
        "tipo": "quantitativa",
        "subtipo": "discreta"
    }                   
])
dictionary.to_csv("../data/external/dictionary.csv", index=False)
dictionary
# Out:
#                   variavel                                          descricao  \
# 0                       ID           Identificador único do indivíduo testado
# 1                      Age                Idade do indivíduo testado, em anos
# 2                   Gender                        Gênero do indivíduo testado
# 3                  Bedtime  O horário em que o indivíduo testado vai para ...
# 4              Wakeup time  O horário em que o indivíduo testado acorda to...
# 5           Sleep duration  Quantidade total de tempo em que o indivíduo t...
# 6         Sleep efficiency  Medida da proporção de tempo na cama gasto dor...
# 7     REM sleep percentage        Percentual do tempo total gasto em sono REM
# 8    Deep sleep percentage   Percentual do tempo total gasto em sono profundo
# 9   Light sleep percentage       Percentual do tempo total gasto em sono leve
# 10              Awakenings  O número de vezes em que o indivíduo testado a...
# ...
